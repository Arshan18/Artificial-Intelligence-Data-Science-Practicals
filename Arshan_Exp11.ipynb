# %% [markdown]
# # Experiment 11: NLP with RE
# **Name:** Arshan Attar
# **Roll Number:** 231408

# %%
import re

# %%
import nltk

# %%
import re

chat1 = 'MHSSCOE: Hello, I am having an issue with my ticket # 4128899120'

pattern = r'ticket[^\d]*(\d*)'
matches = re.findall(pattern, chat1)

matches
# Out:
# ['4128899120']

# %%
chat2 = 'MHSSCOE: I have a problem with my ticket number 4128899120'

pattern = r'ticket[^\d]*(\d*)'
matches = re.findall(pattern, chat2)

matches
# Out:
# ['4128899120']

# %%
chat3 = 'MHSSCOE: My ticket 4128899120 is having an issue, I was charged 300$ when online it says 280$'
pattern = r'ticket[^\d]*(\d*)'
matches = re.findall(pattern, chat3)
matches
# Out:
# ['4128899120']

# %%
def get_pattern_match(pattern, text):
    matches = re.findall(pattern, text)

    if matches:
        return matches[0]

# %%
get_pattern_match(r'ticket[^\d]*(\d*)', chat1)
# Out:
# '4128899120'

# %%
chat1 = 'MHSSCOE: you ask lot of questions 😠  9876543210, user@gmail.com'
chat2 = 'MHSSCOE: here it is: (987)-654-3210, user@gmail.com'
chat3 = 'MHSSCOE: yes, phone: 9876543210 email: user@gmail.com'

# %%
get_pattern_match(r'[a-zA-Z0-9_]*@[a-z]*\.[a-zA-Z0-9]*', chat1)
# Out:
# 'user@gmail.com'

# %%
get_pattern_match(r'(\d{10})|(\(\d{3}\)-\d{3}-\d{4})', chat2)
# Out:
# ('', '(987)-654-3210')

# %%
get_pattern_match(r'(\d{10})|(\(\d{3}\)-\d{3}-\d{4})', chat3)
# Out:
# ('9876543210', '')

# %%
text = '''
Born    Ratan Naval Tata

December 28, 1937 (age 86)

Mumbai, Maharashtra, India

Nationality
Indian

Education
Cornell University (B.Arch.)
Harvard Business School (Advanced Management Program)

Title
Chairman Emeritus of Tata Sons
Former Chairman of Tata Group
Former Chairman of Tata Motors
Former Chairman of Tata Steel

Spouse(s)
Never married
'''

# %%
get_pattern_match(r'age (\d+)', text)
# Out:
# '86'

# %%
get_pattern_match(r'Born(.*)\n', text).strip()
# Out:
# 'Ratan Naval Tata'

# %%
get_pattern_match(r'Born.*\n\n(.*)\(age', text).strip()
# Out:
# 'December 28, 1937'

# %%
get_pattern_match(r'\(age.*\n\n(.*)', text)
# Out:
# 'Mumbai, Maharashtra, India'

# %%
def extract_personal_information(text):
    age = get_pattern_match(r'age (\d+)', text)
    full_name = get_pattern_match(r'Born\s+(.*)', text)
    birth_date = get_pattern_match(r'\n\n(.*)\(age', text)
    birth_place = get_pattern_match(r'\(age.*\n\n(.*)', text)

    return {
        'age': int(age),
        'name': full_name.strip(),
        'birth_date': birth_date.strip(),
        'birth_place': birth_place.strip()
    }

# %%
extract_personal_information(text)
# Out:
# {'age': 86,
#  'name': 'Ratan Naval Tata',
#  'birth_date': 'December 28, 1937',
#  'birth_place': 'Mumbai, Maharashtra, India'}

# %%
text = '''
Born    Sundar Pichai

July 12, 1972 (age 53)

Madurai, Tamil Nadu, India

Nationality

Indian

Education
Indian Institute of Technology Kharagpur (B.Tech.)
Stanford University (M.S.)
Wharton School of the University of Pennsylvania (MBA)

Occupation
CEO of Alphabet Inc.
CEO of Google

Spouse(s)

Anjali Pichai

Children

2

Parent(s)

Regunatha Pichai (father)
Lakshmi Pichai (mother)

'''

# %%
extract_personal_information(text)
# Out:
# {'age': 53,
#  'name': 'Sundar Pichai',
#  'birth_date': 'July 12, 1972',
#  'birth_place': 'Madurai, Tamil Nadu, India'}
